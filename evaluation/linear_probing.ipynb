# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
# feature_dim: the dimension of the features
# num_classes: the number of classes
linear_classifier = nn.Linear(feature_dim, num_classes)

# Defining the loss function and optimizer for the linear classifier
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(linear_classifier.parameters(), lr=0.001)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in dataloader:
        # Extract features from the model
        with torch.no_grad(): # Ensures that no gradients are computed for the foundation model
            features = foundation_model(inputs)

        # Pass features through the linear classifier
        outputs = linear_classifier(features)

        # Calculate loss and perform backpropagation
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print(f"Epoch {epoch+1}, Loss: {loss.item()}")
